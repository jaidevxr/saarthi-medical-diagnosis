# %% [markdown]
# # 📥 01. Data Ingestion & Loading
# **Project:** Saarthi Medical Diagnosis AI
#
# Loads raw and processed clinical datasets across 168 diseases and 397 symptom features.

# %%
import os, sys, pandas as pd
sys.path.insert(0, '..')
from src.utils.constants import PROCESSED_DATA_DIR
df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR, 'Training.csv'))
print(f"Loaded Training Dataset: {df.shape}")
df.head()
