# %% [markdown]
# # 🧹 02. Data Cleaning & Schema Hygiene
# **Project:** Saarthi Medical Diagnosis AI
#
# Performs column deduplication, whitespace stripping, missing value checks, and symptom normalization.

# %%
import os, sys, pandas as pd
sys.path.insert(0, '..')
from src.utils.constants import PROCESSED_DATA_DIR
df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR, 'Training.csv'))
df = df.loc[:, ~df.columns.duplicated()]
print(f"Missing values count: {df.isnull().sum().sum()}")
print("[OK] Schema hygiene passed cleanly.")
