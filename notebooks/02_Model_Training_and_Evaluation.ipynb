# %% [markdown]
# # 🧪 02. Machine Learning Training, Calibration & Evaluation
# **Project:** Saarthi — AI Medical Diagnosis System
# **Module:** Model Architecture & Evaluation Suite
#
# ---
# ### Overview
# This notebook details model training, feature scaling, label encoding, and performance benchmarks:
# 1. **Model Pipeline:** Random Forest, Calibrated Naive Bayes, Decision Trees, and Logistic Regression.
# 2. **Evaluation Metrics:** Top-1 Accuracy, Top-2 Accuracy, Top-3 Accuracy, Precision, Recall, and F1 Score.

# %%
import os, sys, joblib
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, accuracy_score, f1_score

PROJECT_ROOT = ".."
sys.path.insert(0, PROJECT_ROOT)

from utils.data_loader import load_testing_data
from models.predictor import DiseasePredictor

predictor = DiseasePredictor(models_dir="../models")
print("[OK] Predictor module loaded successfully.")

# %% [markdown]
# ## 1. Test Set Evaluation

# %%
df_test = load_testing_data()
X_test = df_test[predictor.symptom_columns]
y_test = predictor.encoder.transform(df_test['prognosis'])

X_sc = predictor.scaler.transform(X_test)
y_pred = predictor.primary_model.predict(X_sc)

print(f"Model Tested: {predictor.primary_model}")
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)*100:.2f}%")
print(f"Macro F1-Score:{f1_score(y_test, y_pred, average='macro'):.4f}")
