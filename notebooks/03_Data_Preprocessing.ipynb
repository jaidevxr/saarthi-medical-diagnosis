# %% [markdown]
# # ⚙️ 03. Data Preprocessing & Target Label Encoding
# **Project:** Saarthi Medical Diagnosis AI
#
# Applies LabelEncoder to target disease prognoses and Standard/MinMax scaling.

# %%
import os, sys, joblib, pandas as pd
sys.path.insert(0, '..')
from src.utils.constants import MODELS_DIR
encoder = joblib.load(os.path.join(MODELS_DIR, 'encoder.pkl'))
print(f"Total Target Disease Classes Encoded: {len(encoder.classes)}")
