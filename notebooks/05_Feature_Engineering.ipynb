# %% [markdown]
# # 🔧 05. Feature Engineering & Symptom Schema
# **Project:** Saarthi Medical Diagnosis AI
#
# Indexes 397 binary symptom indicators and maps medical synonym co-occurrence.

# %%
import os, sys, joblib
sys.path.insert(0, '..')
from src.utils.constants import MODELS_DIR
cols = joblib.load(os.path.join(MODELS_DIR, 'symptom_columns.pkl'))
print(f"Indexed Binary Symptom Features: {len(cols)} columns")
