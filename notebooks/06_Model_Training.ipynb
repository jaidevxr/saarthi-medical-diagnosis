# %% [markdown]
# # 🏋️ 06. Model Training & Calibration Pipeline
# **Project:** Saarthi Medical Diagnosis AI
#
# Trains Calibrated Naive Bayes and Random Forest classifiers.

# %%
import os, sys, joblib
sys.path.insert(0, '..')
from src.utils.constants import MODELS_DIR
model = joblib.load(os.path.join(MODELS_DIR, 'best_model.pkl'))
print(f"Loaded Primary Calibrated Classifier: {model}")
