# %% [markdown]
# # 📈 07. Model Benchmark & Comparison
# **Project:** Saarthi Medical Diagnosis AI
#
# Compares Random Forest, Naive Bayes, Decision Trees, KNN, SVM, and Logistic Regression.

# %%
import os, sys, pandas as pd
sys.path.insert(0, '..')
from src.utils.constants import MODELS_DIR
df_res = pd.read_csv(os.path.join(MODELS_DIR, 'model_results.csv'))
df_res
