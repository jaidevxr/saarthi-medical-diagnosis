# %% [markdown]
# # 🎯 08. Model Evaluation & Top-N Metrics
# **Project:** Saarthi Medical Diagnosis AI
#
# Evaluates Top-1, Top-2, Top-3, Top-5 Accuracy, Precision, Recall, and F1 Score.

# %%
import os, sys, json
sys.path.insert(0, '..')
from src.utils.constants import MODELS_DIR
with open(os.path.join(MODELS_DIR, 'model_metadata.json')) as f:
    meta = json.load(f)
print("Evaluation Summary:")
print(json.dumps(meta, indent=2))
