# %% [markdown]
# # 🚀 09. Final Inference & Conversational NLP Demo
# **Project:** Saarthi Medical Diagnosis AI
#
# Demonstrates free-text symptom parsing with Hinglish support and Top-3 differential diagnosis generation.

# %%
import os, sys
sys.path.insert(0, '..')
from models.predictor import DiseasePredictor
predictor = DiseasePredictor(models_dir='../models')
res = predictor.predict_from_text('I have high bukhar, sir dard, and gale me dard')
print(f"Top Diagnosis:    {res['top_prediction']['disease']} ({res['top_prediction']['confidence']}%)")
print(f"Top 3 Candidates: {[p['disease'] for p in res['top_3']]}")
